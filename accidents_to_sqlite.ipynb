# %%
import pandas as pd
import numpy as np
import os
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float
import sqlite3

# %%
engine = create_engine("sqlite:///Merged_Drivers_Data.sqlite")

# %%
con = sqlite3.connect("Merged_Drivers_Data.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM Accidents",con)
df
# Out:
#        index  STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  \
# 0          0      1    10001         1         1         0     0           0
# 1          1      1    10002         1         1         0     0           0
# 2          2      1    10003         2         1         1     0           1
# 3          3      1    10004         1         1         0     0           0
# 4          4      1    10005         1         1         0     0           0
# 5          5      1    10006         1         1         0     0           0
# 6          6      1    10007         1         1         0     0           0
# 7          7      1    10008         1         1         0     0           0
# 8          8      1    10009         2         2         0     0           0
# 9          9      1    10010         1         1         0     0           0
# 10        10      1    10011         2         2         0     0           0
# ...

# %%
accidents = pd.read_csv('accident.csv')

# %%
accidents.to_sql("Accidents",con,if_exists="replace",flavor='sqlite')
# Out:
# C:\Users\bg22675\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py:531: FutureWarning: the 'flavor' parameter is deprecated and will be removed in a future version, as 'sqlite' is the only supported option when SQLAlchemy is not installed.
#   _validate_flavor_parameter(flavor)

# %%
con.execute("INSERT INTO Accidents(Id INT PRIMARY KEY AUTO_INCREMENT")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-44-6c1e2836c0b3> in <module>()
# ----> 1 con.execute("INSERT INTO Accidents(Id INT PRIMARY KEY AUTO_INCREMENT")
#
# OperationalError: near "INT": syntax error

# %%
con.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e2f59a37941c> in <module>()
# ----> 1 conn.commit()
#
# AttributeError: 'Connection' object has no attribute 'commit'
